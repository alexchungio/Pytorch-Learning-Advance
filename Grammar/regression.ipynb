# %% [markdown]
# # 线性回归

# %%
import torch
from time import time
from IPython import display
from matplotlib import pyplot as plt
import numpy as np
import random
import torch.utils.data as Data

# %% [markdown]
# ## tensor sum

# %%
a = torch.ones(1000)
b = torch.ones(1000)

# %% [markdown]
# **method 1: piecewise sum**

# %%
start = time()
c = torch.ones(1000)
for i in range(1000):
    c[i] = a[i] + b[i]
print(time() - start)
# Out:
# 0.008764266967773438

# %% [markdown]
# **method 2: vector sum**

# %%
start = time()
c = a + b
print(time() - start)
# Out:
# 6.580352783203125e-05

# %% [markdown]
# ## generate dataset

# %%
num_inputs = 2
num_examples = 1000
t_w = [2., -3.] # true weights
t_b = 1. # true biases

features = torch.randn(num_examples, num_inputs, dtype=torch.float)
labels = t_w[0] * features[:, 0] + t_w[1] * features[:, 1] + t_b
# add noise
labels += torch.tensor(np.random.normal(0, 0.01, size=labels.size()), dtype=torch.float)

print(features.shape)
print(labels.shape)
# Out:
# torch.Size([1000, 2])
# torch.Size([1000])

# %% [markdown]
# ## show dataset

# %%
def use_svg_display():
    display.set_matplotlib_formats('svg')
    
def set_figsize(fig_size=(6, 4)):
    use_svg_display()
    plt.rcParams['figure.figsize'] = fig_size

set_figsize()

plt.scatter(features[:,1].numpy(), labels.numpy(), 1)

# %%
batch_size = 100

dataset = Data.TensorDataset(features, labels)
data_generator = Data.DataLoader(dataset, batch_size, shuffle=True)

# %%
# read data batch
for x, y in data_generator:
    print(x, y)
    break
# Out:
# tensor([[ 1.4727, -0.4480],
#         [ 1.0368, -1.3214],
#         [ 1.1897, -1.3388],
#         [-1.6191, -1.1633],
#         [ 0.8800,  0.9174],
#         [ 0.7155, -1.0193],
#         [ 0.8013, -0.9444],
#         [ 0.3275, -0.1164],
#         [-0.5294, -2.4055],
#         [ 0.7332,  1.0512],
#         [ 0.3849, -0.9423],
#         [ 0.7794, -0.8091],
#         [-0.5894,  0.5064],
#         [-1.8632, -0.3178],
#         [ 0.6678,  0.5204],
#         [ 1.3076, -0.1458],
#         [-0.9913, -0.7465],
#         [-0.2314, -0.8140],
#         [-0.3260,  0.8088],
#         [ 0.1362,  1.0101],
#         [ 1.0578, -0.1774],
#         [-0.3615,  0.5658],
#         [-1.2016,  0.2582],
#         [ 0.6659,  0.4649],
#         [-2.2812,  0.6123],
#         [-0.2063,  0.1614],
#         [ 0.9482, -0.2620],
#         [ 0.9367, -0.2154],
#         [ 0.0243,  0.7895],
#         [-0.1959, -1.0351],
#         [ 1.4502, -1.1096],
#         [-1.5188, -1.2523],
#         [-1.3169,  0.3931],
#         [-1.1031,  1.1779],
#         [-1.4769,  1.7795],
#         [ 1.2583,  0.2833],
#         [ 1.6130,  0.3345],
#         [ 0.1961,  0.4201],
#         [ 0.0060,  1.4335],
#         [ 1.2381, -0.0433],
#         [ 0.0705, -0.7966],
#         [ 0.3003,  0.2049],
#         [-1.1165, -0.7739],
#         [ 0.9541, -1.2511],
#         [ 0.8177, -1.1889],
#         [ 0.6412, -0.8024],
#         [-0.8477, -0.5619],
#         [-0.6859,  1.6241],
#         [-0.4365, -0.7989],
#         [-0.8331,  0.0897],
#         [-0.1070, -0.6611],
#         [-0.3518,  0.6305],
#         [ 1.0631, -0.8480],
#         [-0.2587,  0.4349],
#         [ 0.9966,  2.0017],
#         [ 1.0776, -1.7423],
#         [ 0.0792, -0.3383],
#         [ 0.2059,  1.4233],
#         [-0.1520,  0.7754],
#         [ 0.5206, -0.5094],
#         [-1.0998,  1.0493],
#         [ 0.6191, -0.2158],
#         [ 1.5409,  0.5757],
#         [ 1.1987,  0.7403],
#         [ 0.9476,  0.3766],
#         [-1.0691,  0.0691],
#         [-1.5281, -0.7925],
#         [-0.1212,  0.3627],
#         [-1.1278,  1.3907],
#         [-0.8172, -0.3070],
#         [ 0.4272,  0.5027],
#         [ 1.3168, -0.7271],
#         [ 0.9926, -0.5738],
#         [-1.0871, -0.7182],
#         [-1.8633,  0.2124],
#         [ 0.0386, -1.9782],
#         [ 0.6942,  0.1983],
#         [-1.2899, -1.6357],
#         [-1.8218,  0.0250],
#         [ 0.3449,  1.8202],
#         [ 0.5136, -0.1612],
#         [-1.2276,  0.2567],
#         [-0.3673, -0.1234],
#         [ 0.0626,  1.0552],
#         [ 0.6229,  1.3946],
#         [ 1.3659, -2.2865],
#         [ 0.5931,  0.8420],
#         [-1.4252,  1.3692],
#         [-2.3651, -0.7282],
#         [ 0.0989,  0.1107],
#         [-1.0914, -1.0466],
#         [ 1.1110, -0.5197],
#         [-1.2128,  0.5470],
#         [-0.7247, -0.3466],
#         [ 1.2572,  0.8326],
#         [-1.2060,  0.4852],
#         [ 0.0839, -0.3765],
#         [-0.4487, -0.4231],
#         [ 0.2209,  0.6799],
#         [-0.6189, -0.5036]]) tensor([ 5.2831,  7.0621,  7.4087,  1.2650,  0.0132,  5.4778,  5.4412,  1.9963,
#          7.1522, -0.7038,  4.5918,  4.9934, -1.7033, -1.7796,  0.7700,  4.0690,
#          1.2562,  2.9629, -2.0776, -1.7678,  3.6491, -1.4323, -2.1796,  0.9411,
#         -5.4153,  0.1017,  3.6779,  3.5366, -1.3142,  3.7074,  7.2313,  1.7295,
#         -2.8178, -4.7309, -7.3007,  2.6663,  3.2013,  0.1349, -3.2969,  3.6074,
#          3.5391,  0.9835,  1.0893,  6.6656,  6.1924,  4.6898,  1.0004, -5.2532,
#          2.5244, -0.9325,  2.7631, -1.5953,  5.6606, -0.8140, -3.0201,  8.3947,
#          2.1764, -2.8633, -1.6295,  3.5778, -4.3666,  2.8943,  2.3690,  1.1885,
#          1.7688, -1.3379,  0.3212, -0.3279, -5.4345,  0.3014,  0.3249,  5.8221,
#          4.6999,  0.9919, -3.3712,  7.0167,  1.8089,  3.3508, -2.7444, -3.7656,
#          2.5027, -2.2302,  0.6364, -2.0372, -1.9301, 10.5839, -0.3236, -5.9486,
#         -1.5379,  0.8688,  1.9589,  4.7866, -3.0804,  0.6020,  1.0125, -2.8703,
#          2.2900,  1.3776, -0.6046,  1.2645])

# %% [markdown]
# ## initial model parameter

# %%
# initial w and b
w = torch.tensor(np.random.normal(0, 0.01, (num_inputs, 1)), dtype=torch.float32)
b = torch.zeros(1, dtype=torch.float32)

# %%
# set requires grad
w.requires_grad_(requires_grad=True)
b.requires_grad_(requires_grad=True)
# Out:
# tensor([0.], requires_grad=True)

# %% [markdown]
# ## define model

# %%
def linear_regression(x, w, b):
    return torch.mm(x, w) + b

# %% [markdown]
# ## define loss function

# %%
def squared_loss(y_pred, y):
    return (y_pred - y.view(y_pred.size())) ** 2

# %% [markdown]
# ## define optimizer

# %%
def sgd(params, lr, batch_size):
    for param in params:
        param.data -= lr * param.grad / batch_size

# %% [markdown]
# ## train model

# %%
lr = 0.01
num_epochs = 20
net = linear_regression
loss = squared_loss

for epoch in range(num_epochs):
    for x, y in data_generator:
        l = loss(net(x, w, b), y).sum()  # computer batch loss
        l.backward() # use loss to compute grad
        sgd([w, b], lr, batch_size) # updata parameter
        
        # zero clearn grad
        w.grad.data.zero_()
        b.grad.data.zero_()
        
    epoch_loss = loss(net(features, w, b), labels).mean() # epoch loss
    print('epoch {} => loss {:.4}'.format(epoch+1, epoch_loss))
# Out:
# epoch 1 => loss 9.256
# epoch 2 => loss 6.182
# epoch 3 => loss 4.133
# epoch 4 => loss 2.766
# epoch 5 => loss 1.853
# epoch 6 => loss 1.243
# epoch 7 => loss 0.8347
# epoch 8 => loss 0.561
# epoch 9 => loss 0.3776
# epoch 10 => loss 0.2544
# epoch 11 => loss 0.1716
# epoch 12 => loss 0.1159
# epoch 13 => loss 0.07837
# epoch 14 => loss 0.05307
# epoch 15 => loss 0.03598
# epoch 16 => loss 0.02444
# epoch 17 => loss 0.01663
# epoch 18 => loss 0.01133
# epoch 19 => loss 0.007745
# epoch 20 => loss 0.005309

# %%
print(t_w, '<=>', w.data)
print(t_b, '<=>', b.data)
# Out:
# [2.0, -3.0] <=> tensor([[ 1.9777],
#         [-2.9297]])
# 1.0 <=> tensor([0.9925])
